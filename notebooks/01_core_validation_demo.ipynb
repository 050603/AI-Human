# %% [markdown]
# # Notebook 级核心验证版
#
# 本 Notebook 演示纯文本课堂转录稿的最小闭环：切片 → 多次采样 → 语义聚类 → 语义熵/分数熵 → 自动通过或人工审核。

# %%
from classroom_ai.pipeline.core_validation import run_core_validation

result = run_core_validation(
    transcript_path='../data/sample/lesson_001.json',
    config_path='../configs/local_mock.yaml',
)
result['slice_count']

# %%
for item in result['results']:
    print(item['slice_id'], item['majority_score'], item['score_entropy'], item['semantic_entropy'], item['decision'])
